# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("used_phone_price_prediction_cleaned.csv")

# %%
df.head(5)
# Out:
#    brand  release_year  ram_gb  storage_gb  screen_size_inches  \
# 0      0          2025       4         256                6.93
# 1      1          2024      16          64                6.29
# 2      2          2022       4         128                5.52
# 3      3          2024      16         512                5.99
# 4      3          2021       4         128                6.59
#
#    battery_capacity  camera_score  os_type  has_5g  original_price  ...  \
# 0              4130           100        0       1          147337  ...
# 1              5558            67        0       1           75725  ...
# 2              5945            67        1       1          134358  ...
# 3              5767            57        0       1           96807  ...
# 4              5336            44        0       1           74505  ...
#
#    screen_cracked  body_damage  repair_history  water_damage  city_tier  \
# 0               0            0               0             0          0
# ...

# %%
df.shape
# Out:
# (1000000, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   brand                      1000000 non-null  int64
#  1   release_year               1000000 non-null  int64
#  2   ram_gb                     1000000 non-null  int64
#  3   storage_gb                 1000000 non-null  int64
#  4   screen_size_inches         1000000 non-null  float64
#  5   battery_capacity           1000000 non-null  int64
#  6   camera_score               1000000 non-null  int64
#  7   os_type                    1000000 non-null  int64
#  8   has_5g                     1000000 non-null  int64
#  9   original_price             1000000 non-null  int64
#  10  purchase_year              1000000 non-null  int64
#  11  age_months                 1000000 non-null  int64
#  12  usage_hours_per_day        1000000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 brand    release_year          ram_gb      storage_gb  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         3.002193     2022.001836        9.201878      396.798912
# std          1.999934        2.001558        4.309755      349.401760
# min          0.000000     2019.000000        4.000000       64.000000
# 25%          1.000000     2020.000000        6.000000      128.000000
# 50%          3.000000     2022.000000        8.000000      256.000000
# 75%          5.000000     2024.000000       12.000000      512.000000
# max          6.000000     2025.000000       16.000000     1024.000000
#
#        screen_size_inches  battery_capacity    camera_score         os_type  \
# count       1000000.00000    1000000.000000  1000000.000000  1000000.000000
# mean              6.25037       4750.004425       69.980058        0.142690
# std               0.43290       1009.971322       17.607651        0.349757
# ...

# %%
df_ndarray = df.to_numpy()

# %%
df_ndarray
# Out:
# array([[0.000000e+00, 2.025000e+03, 4.000000e+00, ..., 1.000000e+00,
#         1.000000e+00, 4.789146e+04],
#        [1.000000e+00, 2.024000e+03, 1.600000e+01, ..., 1.000000e+00,
#         0.000000e+00, 1.766321e+04],
#        [2.000000e+00, 2.022000e+03, 4.000000e+00, ..., 0.000000e+00,
#         1.000000e+00, 6.726820e+04],
#        ...,
#        [2.000000e+00, 2.022000e+03, 4.000000e+00, ..., 0.000000e+00,
#         1.000000e+00, 3.123616e+04],
#        [2.000000e+00, 2.023000e+03, 1.200000e+01, ..., 1.000000e+00,
#         1.000000e+00, 1.628820e+04],
#        [0.000000e+00, 2.020000e+03, 1.600000e+01, ..., 1.000000e+00,
#         1.000000e+00, 9.819030e+03]], shape=(1000000, 25))

# %%
df_ndarray[0].sum()
# Out:
# np.float64(203922.09)

# %%
df_ndarray.shape
# Out:
# (1000000, 25)

# %%
df_ndarray.size
# Out:
# 25000000

# %%
df_ndarray.dtype
# Out:
# dtype('float64')

# %%
type(df_ndarray)
# Out:
# numpy.ndarray

# %%
df_ndarray.ndim
# Out:
# 2

# %%
df_ndarray = df.to_numpy()

# %%
df_ndarray[6]
# Out:
# array([2.00000e+00, 2.02500e+03, 4.00000e+00, 2.56000e+02, 5.80000e+00,
#        5.57200e+03, 4.60000e+01, 1.00000e+00, 1.00000e+00, 1.27845e+05,
#        2.02500e+03, 4.30000e+01, 1.07000e+01, 1.00000e+00, 6.00000e+01,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00,
#        1.00000e+00, 1.50000e+01, 1.00000e+00, 1.00000e+00, 1.58630e+04])

# %%
ram = df_ndarray[:, 2]

# %%
ram
# Out:
# array([ 4., 16.,  4., ...,  4., 12., 16.], shape=(1000000,))

# %%
year = df_ndarray[:, 1]
year
# Out:
# array([2025., 2024., 2022., ..., 2022., 2023., 2020.], shape=(1000000,))

# %%
type(year)
# Out:
# numpy.ndarray

# %%
year.max()
# Out:
# np.float64(2025.0)

# %%
year.min()
# Out:
# np.float64(2019.0)

# %%
## Normalization of data
battery = df_ndarray[:,5]

normalized = (battery - np.mean(battery)) / np.std(battery)

# %%
normalized[0:100]
# Out:
# array([-0.61388351,  0.80001873,  1.18319812,  1.00695541,  0.5802104 ,
#         1.52380202,  0.81388052, -0.26832897,  0.40594794,  1.03863949,
#         0.76239389, -1.48222543,  1.34062841, -1.71688567, -1.60698151,
#        -1.21390084,  0.44258266, -0.61487363,  1.54261445, -0.11386906,
#        -0.8465635 ,  1.25448731,  0.38911577, -0.35645032,  1.31686535,
#         0.12970234, -0.60398223,  1.25547744,  0.28317212, -1.6713398 ,
#         0.74655184, -0.49308794,  0.37426386,  1.50102909,  0.08514659,
#         1.52182177, -1.60896176, -0.86537592,  0.00494626, -1.416877  ,
#         1.19606978,  0.29901416,  0.39703679, -1.22182186,  0.08316634,
#         1.41290773, -0.80695839,  0.23762625, -0.7534915 , -0.94161575,
#         1.29112203,  0.18712974, -1.60698151,  1.32478637,  1.30399369,
#         0.01187715,  1.15151404, -0.1871385 , -0.28120063,  1.4762759 ,
#         0.2970339 , -0.15446429, -0.15248403,  1.43073003,  1.45350296,
# ...

# %%
normalized.shape
# Out:
# (1000000,)

# %%
# Phones with RAM greater than 8 GB
high_ram = df_ndarray[df_ndarray[:, 2] > 8]
high_ram[0:5]
# Out:
# array([[1.000000e+00, 2.024000e+03, 1.600000e+01, 6.400000e+01,
#         6.290000e+00, 5.558000e+03, 6.700000e+01, 0.000000e+00,
#         1.000000e+00, 7.572500e+04, 2.024000e+03, 4.900000e+01,
#         2.000000e+00, 1.000000e+00, 9.800000e+01, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 2.000000e+00,
#         1.000000e+00, 8.000000e+00, 1.000000e+00, 0.000000e+00,
#         1.766321e+04],
#        [3.000000e+00, 2.024000e+03, 1.600000e+01, 5.120000e+02,
#         5.990000e+00, 5.767000e+03, 5.700000e+01, 0.000000e+00,
#         1.000000e+00, 9.680700e+04, 2.024000e+03, 6.200000e+01,
#         4.900000e+00, 2.000000e+00, 9.900000e+01, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00, 0.000000e+00,
#         1.000000e+00, 1.100000e+01, 1.000000e+00, 1.000000e+00,
#         1.262626e+04],
#        [5.000000e+00, 2.022000e+03, 1.200000e+01, 1.024000e+03,
#         5.510000e+00, 4.479000e+03, 4.800000e+01, 0.000000e+00,
# ...

# %%
## Phones with storage equal to 256
phones = df_ndarray[df_ndarray[:, 3] == 256]
phones[0:5]
# Out:
# array([[0.000000e+00, 2.025000e+03, 4.000000e+00, 2.560000e+02,
#         6.930000e+00, 4.130000e+03, 1.000000e+02, 0.000000e+00,
#         1.000000e+00, 1.473370e+05, 2.025000e+03, 5.200000e+01,
#         2.700000e+00, 0.000000e+00, 7.800000e+01, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.100000e+01, 1.000000e+00, 1.000000e+00,
#         4.789146e+04],
#        [2.000000e+00, 2.025000e+03, 4.000000e+00, 2.560000e+02,
#         5.800000e+00, 5.572000e+03, 4.600000e+01, 1.000000e+00,
#         1.000000e+00, 1.278450e+05, 2.025000e+03, 4.300000e+01,
#         1.070000e+01, 1.000000e+00, 6.000000e+01, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         1.000000e+00, 1.500000e+01, 1.000000e+00, 1.000000e+00,
#         1.586300e+04],
#        [0.000000e+00, 2.021000e+03, 6.000000e+00, 2.560000e+02,
#         6.850000e+00, 3.253000e+03, 8.700000e+01, 0.000000e+00,
# ...

# %%
## A Common workflow is:

# 1. Read data
df = pd.read_csv("phones.csv")

# 2. Clean data
# ...

# 3. Encode categorical columns
# ...

# 4. Split features and target
X = df.drop("original_price", axis=1).to_numpy()
y = df["original_price"].to_numpy()

# 5. Use NumPy for numerical operations
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# 6. Train an ML model
