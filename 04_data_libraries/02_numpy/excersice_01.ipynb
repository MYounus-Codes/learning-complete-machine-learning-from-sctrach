# %% [markdown]
# #### Your next practice exercise
#
# ##### **Using your cleaned dataset, try the following:**
#
# - Convert the DataFrame to a NumPy array.
# - Create X (all columns except original_price) and y (original_price only).
# **Print:**
# - X.shape
# - y.shape
#
# **Find the average:**
# - RAM
# - Storage
# - Battery capacity
# - Find the maximum and minimum original_price.
# - Normalize the battery_capacity column using NumPy.
#
# ***These exercises will give you practical experience with the exact NumPy operations you'll repeatedly use in machine learning.***

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("used_phone_price_prediction_cleaned.csv")
df.head(5)
# Out:
#    brand  release_year  ram_gb  storage_gb  screen_size_inches  \
# 0      0          2025       4         256                6.93
# 1      1          2024      16          64                6.29
# 2      2          2022       4         128                5.52
# 3      3          2024      16         512                5.99
# 4      3          2021       4         128                6.59
#
#    battery_capacity  camera_score  os_type  has_5g  original_price  ...  \
# 0              4130           100        0       1          147337  ...
# 1              5558            67        0       1           75725  ...
# 2              5945            67        1       1          134358  ...
# 3              5767            57        0       1           96807  ...
# 4              5336            44        0       1           74505  ...
#
#    screen_cracked  body_damage  repair_history  water_damage  city_tier  \
# 0               0            0               0             0          0
# ...

# %%
df.shape
# Out:
# (1000000, 25)

# %%
new_df = df.to_numpy()
new_df.shape
# Out:
# (1000000, 25)

# %%
new_df[0].shape
# Out:
# (25,)

# %%
new_df[9]
# Out:
# array([0.000000e+00, 2.022000e+03, 4.000000e+00, 1.280000e+02,
#        6.100000e+00, 5.799000e+03, 7.200000e+01, 0.000000e+00,
#        0.000000e+00, 9.620200e+04, 2.023000e+03, 7.000000e+01,
#        3.100000e+00, 0.000000e+00, 7.400000e+01, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#        0.000000e+00, 7.000000e+00, 1.000000e+00, 1.000000e+00,
#        1.991949e+04])

# %%
# - Create X (all columns except original_price) and y (original_price only).
# The index of the original_price column is 9

x = df.drop(columns=['original_price']).to_numpy()
y = df['original_price'].to_numpy()

# %%
x.shape
# Out:
# (1000000, 24)

# %%
y.shape
# Out:
# (1000000,)

# %%
# Taking the average of ram_gb column with numpy


avg_ram = np.mean(df['ram_gb'])
avg_ram
# Out:
# np.float64(9.201878)

# %%
# Taking the average of storage_gb column with pandas
avg_storage = df['storage_gb'].mean()
avg_storage
# Out:
# np.float64(396.798912)

# %%
# Taking the average of battery_capacity column with pandas

avg_battery = df['battery_capacity'].mean()
avg_battery
# Out:
# np.float64(4750.004425)

# %%
# Finding the minimum and maximum of original_price column with numpy

min_price = np.min(y)
max_price = np.max(y)
print(f"Minimum price: {min_price}, \nMaximum price: {max_price}")
# Out:
# Minimum price: 10000,
# Maximum price: 150000

# %%
print(np.mean(y))
# Out:
# 79966.195735

# %%
df.describe()
# Out:
#                 brand    release_year          ram_gb      storage_gb  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         3.002193     2022.001836        9.201878      396.798912
# std          1.999934        2.001558        4.309755      349.401760
# min          0.000000     2019.000000        4.000000       64.000000
# 25%          1.000000     2020.000000        6.000000      128.000000
# 50%          3.000000     2022.000000        8.000000      256.000000
# 75%          5.000000     2024.000000       12.000000      512.000000
# max          6.000000     2025.000000       16.000000     1024.000000
#
#        screen_size_inches  battery_capacity    camera_score         os_type  \
# count       1000000.00000    1000000.000000  1000000.000000  1000000.000000
# mean              6.25037       4750.004425       69.980058        0.142690
# std               0.43290       1009.971322       17.607651        0.349757
# ...

# %%
# Normalize the battery_capacity column using numpy 

df['battery_capacity_normalized'] = (df['battery_capacity'] - np.mean(df['battery_capacity'])) / np.std(df['battery_capacity'])
df['battery_capacity_normalized']
# Out:
# 0        -0.613884
# 1         0.800019
# 2         1.183198
# 3         1.006955
# 4         0.580210
#             ...
# 999995    1.592121
# 999996    1.378253
# 999997    1.112899
# 999998    0.465356
# 999999    1.696084
# Name: battery_capacity_normalized, Length: 1000000, dtype: float64

# %%
x = x + df['battery_capacity_normalized'].to_numpy().reshape(-1, 1)
x.shape
# Out:
# (1000000, 24)

# %%
total_sales = np.sum(y)
total_sales
# Out:
# np.int64(79966195735)
