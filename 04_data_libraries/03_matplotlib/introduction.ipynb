# %%
import matplotlib.pyplot as plt

# %%
## Creating a simple line plot

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]
plt.plot(x, y)
plt.show()

# %%
# Creating another line plot with different style
x = ["Mon", "Tue", "Wed", "Thu", "Fri"]
y = [10, 20, 40, 38, 80]
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=10)
# plt.plot(x, y)
plt.title("Sales over the week")
plt.xlabel("Days of the week")
plt.ylabel("Sales")
plt.grid()
plt.show()

# %%
## Customizing the plot with different styles and colors
# Creating another line plot with different style
x = ["Mon", "Tue", "Wed", "Thu", "Fri"]
y = [10, 20, 40, 38, 80]
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=10, label='Sales')
# plt.plot(x, y)
plt.title("Sales over the week")
plt.xlabel("Days of the week")
plt.ylabel("Sales")
plt.legend()
plt.grid(color="blue", linestyle="--", linewidth=0.5)
# plt.xticks(rotation=45)
plt.xticks(["Mon", "Tue", "Wed", "Thu", "Fri"], ["D1", "D2", "D3", "D4", "D5"])
plt.show()

# %%
## Customizing the plot with different styles and colors
# Creating another line plot with different style
x = ["Mon", "Tue", "Wed", "Thu", "Fri"]
y = [10, 20, 40, 38, 80]
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=10, label='Sales')
# plt.plot(x, y)
plt.title("Sales over the week")
plt.xlabel("Days of the week")
plt.ylabel("Sales")
plt.legend()
plt.grid(color="blue", linestyle="--", linewidth=0.5)
plt.xticks(rotation=45)
plt.xticks(["Mon", "Tue", "Wed", "Thu", "Fri"], ["D1", "D2", "D3", "D4", "D5"])
plt.show()
