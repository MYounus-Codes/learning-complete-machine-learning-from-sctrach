# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sales_data.csv")
# print(df)

# %%
df
# Out:
#    Transaction_ID        Date   Product     Category  Units_Sold  Unit_Price  \
# 0             101  2026-07-01    Laptop  Electronics         1.0        1200
# 1             102  2026-07-01     Mouse  Accessories         4.0          25
# 2             103  2026-07-02   Monitor  Electronics         2.0         300
# 3             104  2026-07-02    Laptop  Electronics         1.0        1200
# 4             105  2026-07-03     Mouse  Accessories         5.0          25
# 5             106  2026-07-03  Keyboard  Accessories         2.0          50
# 6             107  2026-07-04   Monitor  Electronics         NaN         300
# 7             108  2026-07-04    Laptop  Electronics         3.0        1200
# 8             109  2026-07-05     Mouse  Accessories        10.0          25
# 9             110  2026-07-05   Unknown  Accessories         1.0          45
#
#   Region
# 0  North
# 1   East
# 2   West
# 3  South
# 4   East
# 5  North
# 6   West
# 7  North
# 8  South
# 9   East

# %%
## Selecting specific columns
df["Category"].head(5)  # Selecting the 'Category' column and displaying the first 5 rows
# Out:
# 0    Electronics
# 1    Accessories
# 2    Electronics
# 3    Electronics
# 4    Accessories
# Name: Category, dtype: str

# %%
west_sold_products = df[df["Region"] == "West"]["Product"] # Filtering for 'West' region and selecting 'Product' column
west_sold_products
# Out:
# 2    Monitor
# 6    Monitor
# Name: Product, dtype: str

# %%
accessories_mouse = df[(df["Category"] == "Accessories") & (df["Product"] == "Mouse")]  # Filtering for 'Accessories' category and selecting 'Product' column
accessories_mouse
# Out:
#    Transaction_ID        Date Product     Category  Units_Sold  Unit_Price  \
# 1             102  2026-07-01   Mouse  Accessories         4.0          25
# 4             105  2026-07-03   Mouse  Accessories         5.0          25
# 8             109  2026-07-05   Mouse  Accessories        10.0          25
#
#   Region
# 1   East
# 4   East
# 8  South

# %%
accessories_keyboard = df[(df["Category"] == "Accessories") & (df["Product"] == "Keyboard")]  # Filtering for 'Accessories' category and selecting 'Product' column
accessories_keyboard
# Out:
#    Transaction_ID        Date   Product     Category  Units_Sold  Unit_Price  \
# 5             106  2026-07-03  Keyboard  Accessories         2.0          50
#
#   Region
# 5  North
